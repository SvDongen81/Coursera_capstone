# %%
# !pip install jsonstat.py
# !pip install pyjstat
# Out:
# ...
#      |████████████████████████████████| 153kB 11.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 16.0MB/s eta 0:00:01
# ...
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/bc/1e/a1/9cd99df6309314b564b7128c14ecdc0139c9ecbaeb017ec919
# ...
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
# Successfully built jsonstat.py terminaltables
# ...
#   Found existing installation: Click 7.0
#     Uninstalling Click-7.0:
#       Successfully uninstalled Click-7.0
# ...

# %%
#import pandas as pd
#!pip install pyjstat
import jsonstat
import pyjstat
import json
#url='https://json-stat.org/samples/oecd-canada.json'
#url='http://ec.europa.eu/eurostat/wdds/rest/data/v2.1/json/en/nama_10_gdp?geo=EU28&precision=1&na_item=B1GQ&unit=CP_MEUR&time=2010&time=2012'
url='https://ec.europa.eu/eurostat/wdds/rest/data/v2.1/json/en/ilc_lvho02?hhtyp=A1&hhtyp=A1M&hhtyp=A1_GE65&filterNonGeo=1&precision=1&incgrp=A_MD60&tenure=OWN_L&tenure=OWN_NL&tenure=RENT_MKT'
collection=jsonstat.from_url(url)
print(dir(jsonstat))
coll=jsonstat.JsonStatDataSet(url)
print(dir(coll))


#print(dir(collection))
#print(collection)
#oecd=collection.dataset(0)
#print(oecd)
#for d in oecd.dimensions():
#for d in collection.dimensions():
    #print(d)
#print(oecd.value(area='BE', year='2014'))
#collection.value(time='2014')
#collection.value(geo='BE', time='2012',incgrp='A_MD60',hhtyp='A1', tenure='OWN_L')
#df=oecd.to_data_frame()
#df=collection.to_data_frame()
#df
#collection.label
#dir(collection)
#collection.data
#collection.value
#collection._JsonStatDataSet__value(0)
#print(collection.dimensions())
#a=collection.dimension(4)
#dir(a)
#print(dir(a))
#print(a.did)
#a.pos
#a.from_string
#print(a.category)
#len(collection)
#print(dir(collection.dimension(3))
print(collection.dimension(3).category(0))
print(dir(collection.dimension(3).category(1)))
collection.dimension(3).category(1)._asdict
collection.dimension(1).category(1).index
#collection._did2dim
#dir(collection)
#collection.to_data_frame
#collection.to_table
#collection
# Out:
# ['Downloader', 'JsonStatCollection', 'JsonStatDataSet', 'JsonStatDimension', 'JsonStatException', 'JsonStatMalformedJson', 'JsonStatValue', 'OrderedDict', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_examples_dir', 'cache_dir', 'collection', 'dataset', 'dimension', 'download', 'downloader', 'exceptions', 'from_file', 'from_json', 'from_string', 'from_url', 'hashlib', 'json', 'os', 'parse_functions', 'print_function', 'requests', 'time', 'unicode_literals', 'utility', 'validate', 'value', 'version']
# ...

# %%
from urllib.request import urlopen
import pandas as pd
import json
response=urlopen('https://ec.europa.eu/eurostat/wdds/rest/data/v2.1/json/en/ilc_lvho02?hhtyp=A1&hhtyp=A1M&hhtyp=A1_GE65&filterNonGeo=1&precision=1&incgrp=A_MD60&tenure=OWN_L&tenure=OWN_NL&tenure=RENT_MKT')
a=response.read()
print(dir(a))
a.zfill(0)
#json.load(a)
#collection=jsonstat.from_str(a)
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'center', 'count', 'decode', 'endswith', 'expandtabs', 'find', 'fromhex', 'hex', 'index', 'isalnum', 'isalpha', 'isdigit', 'islower', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# ...

# %%
#!pip install pandasdmx
from pandasdmx import Request
#print(dir(Request))
#pandasdmx.api.Request.get('https://ec.europa.eu/eurostat/wdds/rest/data/v2.1/json/en/ilc_lvho02?hhtyp=A1&hhtyp=A1M&hhtyp=A1_GE65&filterNonGeo=1&precision=1&incgrp=A_MD60&tenure=OWN_L&tenure=OWN_NL&tenure=RENT_MKT')

# %%
#!pip install eurostatapiclient
from eurostatapiclient import EurostatAPIClient
dataset=EurostatAPIClient('v2.1','json', 'en').get_dataset('tps00001')
print(dataset.label)
print(dir(dataset))
dataset.total_size
dataframe=dataset.to_dataframe()
dataframe['time']
# Out:
# Population on 1 January
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_dimensions', '_id', '_label', '_lang', '_source', '_updated', '_values', '_version', 'add_dimension', 'add_values', 'create_from_json', 'dimensions', 'id', 'label', 'lang', 'source', 'to_dataframe', 'total_size', 'updated', 'version']
# 0      2008
# 1      2009
# 2      2010
# 3      2011
# 4      2012
# 5      2013
# 6      2014
# 7      2015
# 8      2016
# 9      2017
# 10     2018
# 11     2019
# 12     2008
# 13     2009
# 14     2010
# 15     2011
# 16     2012
# 17     2013
# 18     2014
# 19     2015
# 20     2016
# 21     2017
# 22     2018
# 23     2019
# 24     2008
# 25     2009
# 26     2010
# ...

# %%
#!pip install eurostatapiclient
from eurostatapiclient import EurostatAPIClient
dataset=EurostatAPIClient('v2.1','json', 'en').get_dataset('ilc_lvho02?hhtype=A1&hhtyp=A1M&hhtyp=A1_GE65&filterNonGeo=1&precision=1&incgrp=A_MD60&tenure=OWN_L&tenure=OWN_NL&tenure=RENT_MKT')
#print(dataset.label)
#print(dir(dataset))
#dataset.total_size
dataframe=dataset.to_dataframe()
dataframe['hhtyp']
# Out:
# 0           A1M
# 1           A1M
# 2           A1M
# 3           A1M
# 4           A1M
# 5           A1M
# 6           A1M
# 7           A1M
# 8           A1M
# 9           A1M
# 10          A1M
# 11          A1M
# 12          A1M
# 13          A1M
# 14          A1M
# 15          A1M
# 16          A1M
# 17          A1M
# 18          A1M
# 19          A1M
# 20          A1M
# 21          A1M
# 22          A1M
# 23          A1M
# 24          A1M
# 25          A1M
# 26          A1M
# 27          A1M
# 28          A1M
# 29          A1M
#          ...
# 3330    A1_GE65
# 3331    A1_GE65
# 3332    A1_GE65
# 3333    A1_GE65
# 3334    A1_GE65
# 3335    A1_GE65
# 3336    A1_GE65
# 3337    A1_GE65
# 3338    A1_GE65
# 3339    A1_GE65
# 3340    A1_GE65
# 3341    A1_GE65
# 3342    A1_GE65
# 3343    A1_GE65
# 3344    A1_GE65
# 3345    A1_GE65
# 3346    A1_GE65
# 3347    A1_GE65
# 3348    A1_GE65
# 3349    A1_GE65
# 3350    A1_GE65
# 3351    A1_GE65
# 3352    A1_GE65
# 3353    A1_GE65
# ...
